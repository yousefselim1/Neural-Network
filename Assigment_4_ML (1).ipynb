# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import Dense, Flatten
from keras.models import Sequential
from keras.utils import to_categorical
from keras.datasets import mnist

# %%
# Load MNIST handwritten digit data
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
# Load and preprocess data
(train_X, train_y), (test_X, test_y) = mnist.load_data()
train_X = train_X.reshape(train_X.shape[0], -1) / 255.0
test_X = test_X.reshape(test_X.shape[0], -1) / 255.0
train_y_one_hot = np.eye(10)[train_y]
test_y_one_hot = np.eye(10)[test_y]

# Split training data into training and validation sets
split_idx = int(0.8 * train_X.shape[0])
train_X, val_X = train_X[:split_idx], train_X[split_idx:]
train_y_one_hot, val_y_one_hot = train_y_one_hot[:split_idx], train_y_one_hot[split_idx:]

# Activation functions
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    return sigmoid(x) * (1 - sigmoid(x))

def softmax(x):
    exps = np.exp(x - np.max(x, axis=0, keepdims=True))
    return exps / np.sum(exps, axis=0, keepdims=True)

# Initialize parameters
input_size = 784  # 28x28 pixels flattened
hidden_size = 128  # Number of hidden neurons
output_size = 10  # 10 classes for digits 0-9
w_i_h = np.random.randn(hidden_size, input_size) * 0.01
w_h_o = np.random.randn(output_size, hidden_size) * 0.01
b_i_h = np.zeros((hidden_size, 1))
b_h_o = np.zeros((output_size, 1))

# Forward and backward propagation for batches
def forward_backward_propagate(x_batch, y_batch, w_i_h, b_i_h, w_h_o, b_h_o):
    # Forward pass
    hidden_input = np.dot(w_i_h, x_batch) + b_i_h
    hidden_output = sigmoid(hidden_input)
    final_input = np.dot(w_h_o, hidden_output) + b_h_o
    final_output = softmax(final_input)

    # Compute error and cost (Cross-entropy loss)
    m = x_batch.shape[1]
    error = final_output - y_batch
    cost = 0.5 * np.sum(error ** 2)

    # # Backward pass
    delta_output = final_output - y_batch
    delta_hidden = np.dot(w_h_o.T, delta_output) * sigmoid_derivative(hidden_input)

    # Gradient for weights and biases
    grad_w_h_o = np.dot(delta_output, hidden_output.T)
    grad_b_h_o = np.sum(delta_output, axis=1, keepdims=True)
    grad_w_i_h = np.dot(delta_hidden, x_batch.T)
    grad_b_i_h = np.sum(delta_hidden, axis=1, keepdims=True)

    # Update weights and biases
    w_h_o -= learn_rate * grad_w_h_o
    b_h_o -= learn_rate * grad_b_h_o
    w_i_h -= learn_rate * grad_w_i_h
    b_i_h -= learn_rate * grad_b_i_h

    return cost

def calculate_accuracy(predictions, labels):
    return np.mean(np.argmax(predictions, axis=0) == np.argmax(labels, axis=0))

def predict(x, w_i_h, b_i_h, w_h_o, b_h_o):
    # Perform a forward pass to get predictions
    hidden_input = np.dot(w_i_h, x) + b_i_h
    hidden_output = sigmoid(hidden_input)
    final_input = np.dot(w_h_o, hidden_output) + b_h_o
    final_output = softmax(final_input)
    return final_output

# Training the model with mini-batches
epochs = 100
learn_rate = 0.01
batch_size = 64
for epoch in range(epochs):
    train_loss, val_loss = 0, 0
    train_acc, val_acc = 0, 0

    # Training phase
    for i in range(0, train_X.shape[0], batch_size):
        x_batch = train_X[i:i + batch_size].T
        y_batch = train_y_one_hot[i:i + batch_size].T
        cost = forward_backward_propagate(x_batch, y_batch, w_i_h, b_i_h, w_h_o, b_h_o)
        train_loss += cost
        train_acc += calculate_accuracy(predict(x_batch, w_i_h, b_i_h, w_h_o, b_h_o), y_batch)

    # Validation phase
    val_predictions = predict(val_X.T, w_i_h, b_i_h, w_h_o, b_h_o)
    val_loss = -np.sum(val_y_one_hot * np.log(val_predictions.T + 1e-8)) / val_X.shape[0]
    val_acc = calculate_accuracy(val_predictions, val_y_one_hot.T)

    # Logging
    print(f"Epoch {epoch+1}/100")
    print(f"3/3 [==============================] - 0s 18ms/step - loss: {train_loss/train_X.shape[0]:.4f} - accuracy: {train_acc/(train_X.shape[0]//batch_size):.4f} - val_loss: {val_loss:.4f} - val_accuracy: {val_acc:.4f}")

# Evaluate the model on test data
test_predictions = predict(test_X.T, w_i_h, b_i_h, w_h_o, b_h_o)
test_accuracy = calculate_accuracy(test_predictions, test_y_one_hot.T)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1192 - accuracy: 0.8714 - val_loss: 0.2894 - val_accuracy: 0.9137
# Epoch 2/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0532 - accuracy: 0.9558 - val_loss: 0.2068 - val_accuracy: 0.9416
# Epoch 3/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0403 - accuracy: 0.9688 - val_loss: 0.1669 - val_accuracy: 0.9530
# Epoch 4/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0324 - accuracy: 0.9771 - val_loss: 0.1438 - val_accuracy: 0.9580
# Epoch 5/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0270 - accuracy: 0.9823 - val_loss: 0.1288 - val_accuracy: 0.9615
# Epoch 6/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0231 - accuracy: 0.9856 - val_loss: 0.1185 - val_accuracy: 0.9640
# Epoch 7/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0201 - accuracy: 0.9885 - val_loss: 0.1110 - val_accuracy: 0.9669
# Epoch 8/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0178 - accuracy: 0.9912 - val_loss: 0.1052 - val_accuracy: 0.9687
# Epoch 9/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0158 - accuracy: 0.9927 - val_loss: 0.1008 - val_accuracy: 0.9697
# Epoch 10/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0141 - accuracy: 0.9938 - val_loss: 0.0972 - val_accuracy: 0.9708
# Epoch 11/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0126 - accuracy: 0.9950 - val_loss: 0.0944 - val_accuracy: 0.9716
# Epoch 12/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0113 - accuracy: 0.9959 - val_loss: 0.0921 - val_accuracy: 0.9723
# Epoch 13/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0102 - accuracy: 0.9966 - val_loss: 0.0902 - val_accuracy: 0.9733
# Epoch 14/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0092 - accuracy: 0.9973 - val_loss: 0.0886 - val_accuracy: 0.9738
# Epoch 15/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0083 - accuracy: 0.9979 - val_loss: 0.0872 - val_accuracy: 0.9746
# Epoch 16/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0074 - accuracy: 0.9981 - val_loss: 0.0861 - val_accuracy: 0.9752
# Epoch 17/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0067 - accuracy: 0.9984 - val_loss: 0.0851 - val_accuracy: 0.9755
# Epoch 18/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0060 - accuracy: 0.9986 - val_loss: 0.0843 - val_accuracy: 0.9758
# Epoch 19/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0054 - accuracy: 0.9988 - val_loss: 0.0837 - val_accuracy: 0.9758
# Epoch 20/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0049 - accuracy: 0.9990 - val_loss: 0.0831 - val_accuracy: 0.9760
# Epoch 21/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0044 - accuracy: 0.9993 - val_loss: 0.0827 - val_accuracy: 0.9764
# Epoch 22/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0040 - accuracy: 0.9994 - val_loss: 0.0824 - val_accuracy: 0.9765
# Epoch 23/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0036 - accuracy: 0.9995 - val_loss: 0.0821 - val_accuracy: 0.9766
# Epoch 24/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0032 - accuracy: 0.9996 - val_loss: 0.0818 - val_accuracy: 0.9764
# Epoch 25/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.0816 - val_accuracy: 0.9764
# Epoch 26/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0026 - accuracy: 0.9997 - val_loss: 0.0814 - val_accuracy: 0.9765
# Epoch 27/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 0.0813 - val_accuracy: 0.9763
# Epoch 28/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.0811 - val_accuracy: 0.9767
# Epoch 29/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 0.0810 - val_accuracy: 0.9768
# Epoch 30/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.0809 - val_accuracy: 0.9768
# Epoch 31/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0808 - val_accuracy: 0.9772
# Epoch 32/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.0808 - val_accuracy: 0.9769
# Epoch 33/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0013 - accuracy: 0.9999 - val_loss: 0.0807 - val_accuracy: 0.9769
# Epoch 34/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.0807 - val_accuracy: 0.9773
# Epoch 35/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0010 - accuracy: 0.9999 - val_loss: 0.0807 - val_accuracy: 0.9775
# Epoch 36/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0009 - accuracy: 0.9999 - val_loss: 0.0808 - val_accuracy: 0.9778
# Epoch 37/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0009 - accuracy: 0.9999 - val_loss: 0.0808 - val_accuracy: 0.9778
# Epoch 38/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0008 - accuracy: 0.9999 - val_loss: 0.0809 - val_accuracy: 0.9781
# Epoch 39/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0007 - accuracy: 0.9999 - val_loss: 0.0809 - val_accuracy: 0.9783
# Epoch 40/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0007 - accuracy: 1.0000 - val_loss: 0.0810 - val_accuracy: 0.9783
# Epoch 41/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0006 - accuracy: 1.0000 - val_loss: 0.0811 - val_accuracy: 0.9782
# Epoch 42/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0006 - accuracy: 1.0000 - val_loss: 0.0812 - val_accuracy: 0.9784
# Epoch 43/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0005 - accuracy: 1.0000 - val_loss: 0.0813 - val_accuracy: 0.9783
# Epoch 44/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0005 - accuracy: 1.0000 - val_loss: 0.0813 - val_accuracy: 0.9783
# Epoch 45/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0004 - accuracy: 1.0000 - val_loss: 0.0814 - val_accuracy: 0.9783
# Epoch 46/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0004 - accuracy: 1.0000 - val_loss: 0.0815 - val_accuracy: 0.9784
# Epoch 47/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0004 - accuracy: 1.0000 - val_loss: 0.0816 - val_accuracy: 0.9783
# Epoch 48/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0004 - accuracy: 1.0000 - val_loss: 0.0817 - val_accuracy: 0.9783
# Epoch 49/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0003 - accuracy: 1.0000 - val_loss: 0.0818 - val_accuracy: 0.9782
# Epoch 50/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0003 - accuracy: 1.0000 - val_loss: 0.0819 - val_accuracy: 0.9782
# Epoch 51/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0003 - accuracy: 1.0000 - val_loss: 0.0820 - val_accuracy: 0.9781
# Epoch 52/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0003 - accuracy: 1.0000 - val_loss: 0.0821 - val_accuracy: 0.9782
# Epoch 53/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0003 - accuracy: 1.0000 - val_loss: 0.0822 - val_accuracy: 0.9782
# Epoch 54/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0002 - accuracy: 1.0000 - val_loss: 0.0823 - val_accuracy: 0.9781
# Epoch 55/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0002 - accuracy: 1.0000 - val_loss: 0.0823 - val_accuracy: 0.9781
# Epoch 56/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0002 - accuracy: 1.0000 - val_loss: 0.0824 - val_accuracy: 0.9781
# Epoch 57/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0002 - accuracy: 1.0000 - val_loss: 0.0825 - val_accuracy: 0.9782
# Epoch 58/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0002 - accuracy: 1.0000 - val_loss: 0.0826 - val_accuracy: 0.9782
# Epoch 59/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0002 - accuracy: 1.0000 - val_loss: 0.0827 - val_accuracy: 0.9782
# Epoch 60/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0002 - accuracy: 1.0000 - val_loss: 0.0827 - val_accuracy: 0.9782
# Epoch 61/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0002 - accuracy: 1.0000 - val_loss: 0.0828 - val_accuracy: 0.9783
# Epoch 62/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0829 - val_accuracy: 0.9783
# Epoch 63/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0830 - val_accuracy: 0.9783
# Epoch 64/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0831 - val_accuracy: 0.9783
# Epoch 65/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0831 - val_accuracy: 0.9783
# Epoch 66/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0832 - val_accuracy: 0.9782
# Epoch 67/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0833 - val_accuracy: 0.9782
# Epoch 68/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0834 - val_accuracy: 0.9782
# Epoch 69/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0834 - val_accuracy: 0.9782
# Epoch 70/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0835 - val_accuracy: 0.9782
# Epoch 71/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0836 - val_accuracy: 0.9782
# Epoch 72/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0836 - val_accuracy: 0.9782
# Epoch 73/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0837 - val_accuracy: 0.9782
# Epoch 74/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0838 - val_accuracy: 0.9782
# Epoch 75/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0839 - val_accuracy: 0.9783
# Epoch 76/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0839 - val_accuracy: 0.9784
# Epoch 77/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0840 - val_accuracy: 0.9784
# Epoch 78/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0841 - val_accuracy: 0.9785
# Epoch 79/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0841 - val_accuracy: 0.9786
# Epoch 80/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0842 - val_accuracy: 0.9786
# Epoch 81/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0843 - val_accuracy: 0.9787
# Epoch 82/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0843 - val_accuracy: 0.9787
# Epoch 83/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0844 - val_accuracy: 0.9787
# Epoch 84/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0845 - val_accuracy: 0.9785
# Epoch 85/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0845 - val_accuracy: 0.9788
# Epoch 86/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0001 - accuracy: 1.0000 - val_loss: 0.0846 - val_accuracy: 0.9788
# Epoch 87/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0000 - accuracy: 1.0000 - val_loss: 0.0847 - val_accuracy: 0.9788
# Epoch 88/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0000 - accuracy: 1.0000 - val_loss: 0.0847 - val_accuracy: 0.9788
# Epoch 89/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0000 - accuracy: 1.0000 - val_loss: 0.0848 - val_accuracy: 0.9788
# Epoch 90/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0000 - accuracy: 1.0000 - val_loss: 0.0849 - val_accuracy: 0.9787
# Epoch 91/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0000 - accuracy: 1.0000 - val_loss: 0.0849 - val_accuracy: 0.9786
# Epoch 92/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0000 - accuracy: 1.0000 - val_loss: 0.0850 - val_accuracy: 0.9787
# Epoch 93/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0000 - accuracy: 1.0000 - val_loss: 0.0850 - val_accuracy: 0.9788
# Epoch 94/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0000 - accuracy: 1.0000 - val_loss: 0.0851 - val_accuracy: 0.9788
# Epoch 95/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0000 - accuracy: 1.0000 - val_loss: 0.0852 - val_accuracy: 0.9788
# Epoch 96/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0000 - accuracy: 1.0000 - val_loss: 0.0852 - val_accuracy: 0.9788
# Epoch 97/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0000 - accuracy: 1.0000 - val_loss: 0.0853 - val_accuracy: 0.9788
# Epoch 98/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0000 - accuracy: 1.0000 - val_loss: 0.0854 - val_accuracy: 0.9788
# Epoch 99/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0000 - accuracy: 1.0000 - val_loss: 0.0854 - val_accuracy: 0.9788
# Epoch 100/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0000 - accuracy: 1.0000 - val_loss: 0.0855 - val_accuracy: 0.9788
# Test Accuracy: 97.93%

# %%
def predict_single_example(x, w_i_h, b_i_h, w_h_o, b_h_o):
    # Perform a forward pass to get predictions
    hidden_input = np.dot(w_i_h, x) + b_i_h
    hidden_output = sigmoid(hidden_input)
    final_input = np.dot(w_h_o, hidden_output) + b_h_o
    final_output = softmax(final_input)

    # Predict the class (index of the highest probability)
    predicted_class = np.argmax(final_output)

    return predicted_class

# Predict classes for all test examples
test_predicted_classes = []
for i in range(len(test_X)):
    x_test_single = test_X[i].reshape(-1, 1)  # Reshape for a single example
    predicted_class = predict_single_example(x_test_single, w_i_h, b_i_h, w_h_o, b_h_o)
    test_predicted_classes.append(predicted_class)
    print(f"Test example {i+1}: Predicted class: {predicted_class}")

# Evaluate the model on test data
test_accuracy = calculate_accuracy(np.eye(10)[test_predicted_classes].T, test_y_one_hot.T)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# Streaming output truncated to the last 5000 lines.
# Test example 5002: Predicted class: 9
# Test example 5003: Predicted class: 9
# Test example 5004: Predicted class: 8
# Test example 5005: Predicted class: 4
# Test example 5006: Predicted class: 1
# Test example 5007: Predicted class: 0
# Test example 5008: Predicted class: 6
# Test example 5009: Predicted class: 0
# Test example 5010: Predicted class: 9
# Test example 5011: Predicted class: 6
# Test example 5012: Predicted class: 8
# Test example 5013: Predicted class: 6
# Test example 5014: Predicted class: 1
# Test example 5015: Predicted class: 1
# Test example 5016: Predicted class: 9
# Test example 5017: Predicted class: 8
# Test example 5018: Predicted class: 9
# Test example 5019: Predicted class: 2
# Test example 5020: Predicted class: 3
# Test example 5021: Predicted class: 5
# Test example 5022: Predicted class: 5
# Test example 5023: Predicted class: 9
# Test example 5024: Predicted class: 4
# Test example 5025: Predicted class: 2
# Test example 5026: Predicted class: 1
# Test example 5027: Predicted class: 9
# Test example 5028: Predicted class: 4
# Test example 5029: Predicted class: 3
# Test example 5030: Predicted class: 9
# Test example 5031: Predicted class: 6
# Test example 5032: Predicted class: 0
# Test example 5033: Predicted class: 4
# Test example 5034: Predicted class: 0
# Test example 5035: Predicted class: 6
# Test example 5036: Predicted class: 0
# Test example 5037: Predicted class: 1
# Test example 5038: Predicted class: 2
# Test example 5039: Predicted class: 3
# Test example 5040: Predicted class: 4
# Test example 5041: Predicted class: 7
# Test example 5042: Predicted class: 8
# Test example 5043: Predicted class: 9
# Test example 5044: Predicted class: 0
# Test example 5045: Predicted class: 1
# Test example 5046: Predicted class: 2
# Test example 5047: Predicted class: 3
# Test example 5048: Predicted class: 4
# Test example 5049: Predicted class: 7
# Test example 5050: Predicted class: 8
# Test example 5051: Predicted class: 9
# Test example 5052: Predicted class: 0
# Test example 5053: Predicted class: 1
# Test example 5054: Predicted class: 2
# Test example 5055: Predicted class: 3
# Test example 5056: Predicted class: 4
# Test example 5057: Predicted class: 5
# Test example 5058: Predicted class: 6
# Test example 5059: Predicted class: 7
# Test example 5060: Predicted class: 8
# Test example 5061: Predicted class: 9
# Test example 5062: Predicted class: 8
# Test example 5063: Predicted class: 3
# Test example 5064: Predicted class: 4
# Test example 5065: Predicted class: 7
# Test example 5066: Predicted class: 8
# Test example 5067: Predicted class: 6
# Test example 5068: Predicted class: 3
# Test example 5069: Predicted class: 4
# Test example 5070: Predicted class: 0
# Test example 5071: Predicted class: 9
# Test example 5072: Predicted class: 7
# Test example 5073: Predicted class: 1
# Test example 5074: Predicted class: 9
# Test example 5075: Predicted class: 3
# Test example 5076: Predicted class: 8
# Test example 5077: Predicted class: 4
# Test example 5078: Predicted class: 7
# Test example 5079: Predicted class: 3
# Test example 5080: Predicted class: 0
# Test example 5081: Predicted class: 9
# Test example 5082: Predicted class: 1
# Test example 5083: Predicted class: 4
# Test example 5084: Predicted class: 5
# Test example 5085: Predicted class: 4
# Test example 5086: Predicted class: 6
# Test example 5087: Predicted class: 2
# Test example 5088: Predicted class: 0
# Test example 5089: Predicted class: 6
# Test example 5090: Predicted class: 2
# Test example 5091: Predicted class: 1
# Test example 5092: Predicted class: 1
# Test example 5093: Predicted class: 1
# Test example 5094: Predicted class: 1
# Test example 5095: Predicted class: 7
# Test example 5096: Predicted class: 2
# Test example 5097: Predicted class: 4
# Test example 5098: Predicted class: 7
# Test example 5099: Predicted class: 5
# Test example 5100: Predicted class: 2
# Test example 5101: Predicted class: 9
# Test example 5102: Predicted class: 4
# Test example 5103: Predicted class: 5
# Test example 5104: Predicted class: 8
# Test example 5105: Predicted class: 4
# Test example 5106: Predicted class: 2
# Test example 5107: Predicted class: 9
# Test example 5108: Predicted class: 7
# Test example 5109: Predicted class: 0
# Test example 5110: Predicted class: 0
# Test example 5111: Predicted class: 7
# Test example 5112: Predicted class: 5
# Test example 5113: Predicted class: 1
# Test example 5114: Predicted class: 1
# Test example 5115: Predicted class: 7
# Test example 5116: Predicted class: 6
# Test example 5117: Predicted class: 6
# Test example 5118: Predicted class: 6
# Test example 5119: Predicted class: 8
# Test example 5120: Predicted class: 2
# Test example 5121: Predicted class: 2
# Test example 5122: Predicted class: 7
# Test example 5123: Predicted class: 7
# Test example 5124: Predicted class: 4
# Test example 5125: Predicted class: 0
# Test example 5126: Predicted class: 2
# Test example 5127: Predicted class: 4
# Test example 5128: Predicted class: 2
# Test example 5129: Predicted class: 1
# Test example 5130: Predicted class: 8
# Test example 5131: Predicted class: 9
# Test example 5132: Predicted class: 6
# Test example 5133: Predicted class: 1
# Test example 5134: Predicted class: 0
# Test example 5135: Predicted class: 5
# Test example 5136: Predicted class: 9
# Test example 5137: Predicted class: 6
# Test example 5138: Predicted class: 9
# Test example 5139: Predicted class: 8
# Test example 5140: Predicted class: 0
# Test example 5141: Predicted class: 3
# Test example 5142: Predicted class: 0
# Test example 5143: Predicted class: 8
# Test example 5144: Predicted class: 3
# Test example 5145: Predicted class: 9
# Test example 5146: Predicted class: 6
# Test example 5147: Predicted class: 3
# Test example 5148: Predicted class: 0
# Test example 5149: Predicted class: 1
# Test example 5150: Predicted class: 2
# Test example 5151: Predicted class: 3
# Test example 5152: Predicted class: 4
# Test example 5153: Predicted class: 5
# Test example 5154: Predicted class: 6
# Test example 5155: Predicted class: 7
# Test example 5156: Predicted class: 0
# Test example 5157: Predicted class: 1
# Test example 5158: Predicted class: 2
# Test example 5159: Predicted class: 3
# Test example 5160: Predicted class: 4
# Test example 5161: Predicted class: 5
# Test example 5162: Predicted class: 6
# Test example 5163: Predicted class: 7
# Test example 5164: Predicted class: 8
# Test example 5165: Predicted class: 9
# Test example 5166: Predicted class: 0
# Test example 5167: Predicted class: 1
# Test example 5168: Predicted class: 2
# Test example 5169: Predicted class: 3
# Test example 5170: Predicted class: 4
# Test example 5171: Predicted class: 5
# Test example 5172: Predicted class: 6
# Test example 5173: Predicted class: 7
# Test example 5174: Predicted class: 8
# Test example 5175: Predicted class: 5
# Test example 5176: Predicted class: 4
# Test example 5177: Predicted class: 8
# Test example 5178: Predicted class: 7
# Test example 5179: Predicted class: 4
# Test example 5180: Predicted class: 7
# Test example 5181: Predicted class: 7
# Test example 5182: Predicted class: 3
# Test example 5183: Predicted class: 9
# Test example 5184: Predicted class: 8
# Test example 5185: Predicted class: 8
# Test example 5186: Predicted class: 3
# Test example 5187: Predicted class: 1
# Test example 5188: Predicted class: 5
# Test example 5189: Predicted class: 8
# Test example 5190: Predicted class: 2
# Test example 5191: Predicted class: 7
# Test example 5192: Predicted class: 4
# Test example 5193: Predicted class: 2
# Test example 5194: Predicted class: 1
# Test example 5195: Predicted class: 5
# Test example 5196: Predicted class: 4
# Test example 5197: Predicted class: 5
# Test example 5198: Predicted class: 5
# Test example 5199: Predicted class: 8
# Test example 5200: Predicted class: 6
# Test example 5201: Predicted class: 4
# Test example 5202: Predicted class: 4
# Test example 5203: Predicted class: 4
# Test example 5204: Predicted class: 1
# Test example 5205: Predicted class: 8
# Test example 5206: Predicted class: 7
# Test example 5207: Predicted class: 5
# Test example 5208: Predicted class: 5
# Test example 5209: Predicted class: 1
# Test example 5210: Predicted class: 8
# Test example 5211: Predicted class: 9
# Test example 5212: Predicted class: 1
# Test example 5213: Predicted class: 3
# Test example 5214: Predicted class: 6
# Test example 5215: Predicted class: 3
# Test example 5216: Predicted class: 3
# Test example 5217: Predicted class: 2
# Test example 5218: Predicted class: 2
# Test example 5219: Predicted class: 6
# Test example 5220: Predicted class: 9
# Test example 5221: Predicted class: 9
# Test example 5222: Predicted class: 6
# Test example 5223: Predicted class: 5
# Test example 5224: Predicted class: 5
# Test example 5225: Predicted class: 3
# Test example 5226: Predicted class: 3
# Test example 5227: Predicted class: 8
# Test example 5228: Predicted class: 1
# Test example 5229: Predicted class: 6
# Test example 5230: Predicted class: 5
# Test example 5231: Predicted class: 6
# Test example 5232: Predicted class: 8
# Test example 5233: Predicted class: 1
# Test example 5234: Predicted class: 9
# Test example 5235: Predicted class: 7
# Test example 5236: Predicted class: 6
# Test example 5237: Predicted class: 8
# Test example 5238: Predicted class: 3
# Test example 5239: Predicted class: 7
# Test example 5240: Predicted class: 4
# Test example 5241: Predicted class: 7
# Test example 5242: Predicted class: 0
# Test example 5243: Predicted class: 9
# Test example 5244: Predicted class: 0
# Test example 5245: Predicted class: 0
# Test example 5246: Predicted class: 3
# Test example 5247: Predicted class: 7
# Test example 5248: Predicted class: 9
# Test example 5249: Predicted class: 3
# Test example 5250: Predicted class: 0
# Test example 5251: Predicted class: 2
# Test example 5252: Predicted class: 0
# Test example 5253: Predicted class: 1
# Test example 5254: Predicted class: 0
# Test example 5255: Predicted class: 1
# Test example 5256: Predicted class: 0
# Test example 5257: Predicted class: 4
# Test example 5258: Predicted class: 0
# Test example 5259: Predicted class: 1
# Test example 5260: Predicted class: 0
# Test example 5261: Predicted class: 4
# Test example 5262: Predicted class: 7
# Test example 5263: Predicted class: 9
# Test example 5264: Predicted class: 6
# Test example 5265: Predicted class: 2
# Test example 5266: Predicted class: 6
# Test example 5267: Predicted class: 2
# Test example 5268: Predicted class: 2
# Test example 5269: Predicted class: 9
# Test example 5270: Predicted class: 9
# Test example 5271: Predicted class: 0
# Test example 5272: Predicted class: 1
# Test example 5273: Predicted class: 2
# Test example 5274: Predicted class: 3
# Test example 5275: Predicted class: 4
# Test example 5276: Predicted class: 5
# Test example 5277: Predicted class: 6
# Test example 5278: Predicted class: 7
# Test example 5279: Predicted class: 8
# Test example 5280: Predicted class: 9
# Test example 5281: Predicted class: 0
# Test example 5282: Predicted class: 1
# Test example 5283: Predicted class: 2
# Test example 5284: Predicted class: 3
# Test example 5285: Predicted class: 4
# Test example 5286: Predicted class: 5
# Test example 5287: Predicted class: 6
# Test example 5288: Predicted class: 7
# Test example 5289: Predicted class: 8
# Test example 5290: Predicted class: 9
# Test example 5291: Predicted class: 0
# Test example 5292: Predicted class: 1
# Test example 5293: Predicted class: 2
# Test example 5294: Predicted class: 3
# Test example 5295: Predicted class: 4
# Test example 5296: Predicted class: 5
# Test example 5297: Predicted class: 6
# Test example 5298: Predicted class: 7
# Test example 5299: Predicted class: 8
# Test example 5300: Predicted class: 9
# Test example 5301: Predicted class: 8
# Test example 5302: Predicted class: 0
# Test example 5303: Predicted class: 5
# Test example 5304: Predicted class: 6
# Test example 5305: Predicted class: 6
# Test example 5306: Predicted class: 0
# Test example 5307: Predicted class: 8
# Test example 5308: Predicted class: 0
# Test example 5309: Predicted class: 2
# Test example 5310: Predicted class: 3
# Test example 5311: Predicted class: 7
# Test example 5312: Predicted class: 9
# Test example 5313: Predicted class: 4
# Test example 5314: Predicted class: 7
# Test example 5315: Predicted class: 1
# Test example 5316: Predicted class: 9
# Test example 5317: Predicted class: 1
# Test example 5318: Predicted class: 7
# Test example 5319: Predicted class: 1
# Test example 5320: Predicted class: 4
# Test example 5321: Predicted class: 0
# Test example 5322: Predicted class: 0
# Test example 5323: Predicted class: 4
# Test example 5324: Predicted class: 1
# Test example 5325: Predicted class: 7
# Test example 5326: Predicted class: 5
# Test example 5327: Predicted class: 7
# Test example 5328: Predicted class: 1
# Test example 5329: Predicted class: 3
# Test example 5330: Predicted class: 3
# Test example 5331: Predicted class: 3
# Test example 5332: Predicted class: 6
# Test example 5333: Predicted class: 6
# Test example 5334: Predicted class: 9
# Test example 5335: Predicted class: 7
# Test example 5336: Predicted class: 4
# Test example 5337: Predicted class: 3
# Test example 5338: Predicted class: 0
# Test example 5339: Predicted class: 2
# Test example 5340: Predicted class: 5
# Test example 5341: Predicted class: 2
# Test example 5342: Predicted class: 6
# Test example 5343: Predicted class: 0
# Test example 5344: Predicted class: 8
# Test example 5345: Predicted class: 9
# Test example 5346: Predicted class: 4
# Test example 5347: Predicted class: 3
# Test example 5348: Predicted class: 5
# Test example 5349: Predicted class: 4
# Test example 5350: Predicted class: 8
# Test example 5351: Predicted class: 1
# Test example 5352: Predicted class: 5
# Test example 5353: Predicted class: 9
# Test example 5354: Predicted class: 0
# Test example 5355: Predicted class: 6
# Test example 5356: Predicted class: 4
# Test example 5357: Predicted class: 3
# Test example 5358: Predicted class: 6
# Test example 5359: Predicted class: 3
# Test example 5360: Predicted class: 3
# Test example 5361: Predicted class: 8
# Test example 5362: Predicted class: 1
# Test example 5363: Predicted class: 4
# Test example 5364: Predicted class: 7
# Test example 5365: Predicted class: 5
# Test example 5366: Predicted class: 7
# Test example 5367: Predicted class: 2
# Test example 5368: Predicted class: 2
# Test example 5369: Predicted class: 0
# Test example 5370: Predicted class: 0
# Test example 5371: Predicted class: 1
# Test example 5372: Predicted class: 7
# Test example 5373: Predicted class: 7
# Test example 5374: Predicted class: 9
# Test example 5375: Predicted class: 5
# Test example 5376: Predicted class: 9
# Test example 5377: Predicted class: 8
# Test example 5378: Predicted class: 9
# Test example 5379: Predicted class: 6
# Test example 5380: Predicted class: 8
# Test example 5381: Predicted class: 8
# Test example 5382: Predicted class: 2
# Test example 5383: Predicted class: 3
# Test example 5384: Predicted class: 6
# Test example 5385: Predicted class: 1
# Test example 5386: Predicted class: 2
# Test example 5387: Predicted class: 9
# Test example 5388: Predicted class: 8
# Test example 5389: Predicted class: 9
# Test example 5390: Predicted class: 5
# Test example 5391: Predicted class: 2
# Test example 5392: Predicted class: 6
# Test example 5393: Predicted class: 2
# Test example 5394: Predicted class: 4
# Test example 5395: Predicted class: 8
# Test example 5396: Predicted class: 4
# Test example 5397: Predicted class: 6
# Test example 5398: Predicted class: 5
# Test example 5399: Predicted class: 0
# Test example 5400: Predicted class: 1
# Test example 5401: Predicted class: 5
# Test example 5402: Predicted class: 6
# Test example 5403: Predicted class: 7
# Test example 5404: Predicted class: 8
# Test example 5405: Predicted class: 9
# Test example 5406: Predicted class: 0
# Test example 5407: Predicted class: 1
# Test example 5408: Predicted class: 2
# Test example 5409: Predicted class: 3
# Test example 5410: Predicted class: 4
# Test example 5411: Predicted class: 5
# Test example 5412: Predicted class: 6
# Test example 5413: Predicted class: 7
# Test example 5414: Predicted class: 8
# Test example 5415: Predicted class: 9
# Test example 5416: Predicted class: 0
# Test example 5417: Predicted class: 1
# Test example 5418: Predicted class: 2
# Test example 5419: Predicted class: 3
# Test example 5420: Predicted class: 4
# Test example 5421: Predicted class: 5
# Test example 5422: Predicted class: 6
# Test example 5423: Predicted class: 7
# Test example 5424: Predicted class: 8
# Test example 5425: Predicted class: 9
# Test example 5426: Predicted class: 7
# Test example 5427: Predicted class: 4
# Test example 5428: Predicted class: 2
# Test example 5429: Predicted class: 0
# Test example 5430: Predicted class: 9
# Test example 5431: Predicted class: 0
# Test example 5432: Predicted class: 1
# Test example 5433: Predicted class: 5
# Test example 5434: Predicted class: 8
# Test example 5435: Predicted class: 8
# Test example 5436: Predicted class: 0
# Test example 5437: Predicted class: 2
# Test example 5438: Predicted class: 7
# Test example 5439: Predicted class: 8
# Test example 5440: Predicted class: 4
# Test example 5441: Predicted class: 4
# Test example 5442: Predicted class: 6
# Test example 5443: Predicted class: 1
# Test example 5444: Predicted class: 0
# Test example 5445: Predicted class: 4
# Test example 5446: Predicted class: 5
# Test example 5447: Predicted class: 3
# Test example 5448: Predicted class: 9
# Test example 5449: Predicted class: 4
# Test example 5450: Predicted class: 2
# Test example 5451: Predicted class: 0
# Test example 5452: Predicted class: 5
# Test example 5453: Predicted class: 0
# Test example 5454: Predicted class: 1
# Test example 5455: Predicted class: 3
# Test example 5456: Predicted class: 2
# Test example 5457: Predicted class: 9
# Test example 5458: Predicted class: 8
# Test example 5459: Predicted class: 6
# Test example 5460: Predicted class: 0
# Test example 5461: Predicted class: 1
# Test example 5462: Predicted class: 1
# Test example 5463: Predicted class: 8
# Test example 5464: Predicted class: 0
# Test example 5465: Predicted class: 4
# Test example 5466: Predicted class: 7
# Test example 5467: Predicted class: 7
# Test example 5468: Predicted class: 6
# Test example 5469: Predicted class: 3
# Test example 5470: Predicted class: 6
# Test example 5471: Predicted class: 0
# Test example 5472: Predicted class: 7
# Test example 5473: Predicted class: 3
# Test example 5474: Predicted class: 5
# Test example 5475: Predicted class: 4
# Test example 5476: Predicted class: 2
# Test example 5477: Predicted class: 4
# Test example 5478: Predicted class: 1
# Test example 5479: Predicted class: 8
# Test example 5480: Predicted class: 3
# Test example 5481: Predicted class: 5
# Test example 5482: Predicted class: 6
# Test example 5483: Predicted class: 7
# Test example 5484: Predicted class: 0
# Test example 5485: Predicted class: 6
# Test example 5486: Predicted class: 7
# Test example 5487: Predicted class: 1
# Test example 5488: Predicted class: 2
# Test example 5489: Predicted class: 5
# Test example 5490: Predicted class: 8
# Test example 5491: Predicted class: 1
# Test example 5492: Predicted class: 9
# Test example 5493: Predicted class: 3
# Test example 5494: Predicted class: 8
# Test example 5495: Predicted class: 2
# Test example 5496: Predicted class: 8
# Test example 5497: Predicted class: 7
# Test example 5498: Predicted class: 6
# Test example 5499: Predicted class: 7
# Test example 5500: Predicted class: 1
# Test example 5501: Predicted class: 4
# Test example 5502: Predicted class: 6
# Test example 5503: Predicted class: 2
# Test example 5504: Predicted class: 9
# Test example 5505: Predicted class: 3
# Test example 5506: Predicted class: 0
# Test example 5507: Predicted class: 1
# Test example 5508: Predicted class: 2
# Test example 5509: Predicted class: 3
# Test example 5510: Predicted class: 4
# Test example 5511: Predicted class: 5
# Test example 5512: Predicted class: 6
# Test example 5513: Predicted class: 7
# Test example 5514: Predicted class: 0
# Test example 5515: Predicted class: 1
# Test example 5516: Predicted class: 2
# Test example 5517: Predicted class: 3
# Test example 5518: Predicted class: 4
# Test example 5519: Predicted class: 5
# Test example 5520: Predicted class: 0
# Test example 5521: Predicted class: 1
# Test example 5522: Predicted class: 2
# Test example 5523: Predicted class: 8
# Test example 5524: Predicted class: 9
# Test example 5525: Predicted class: 1
# Test example 5526: Predicted class: 4
# Test example 5527: Predicted class: 0
# Test example 5528: Predicted class: 9
# Test example 5529: Predicted class: 5
# Test example 5530: Predicted class: 0
# Test example 5531: Predicted class: 8
# Test example 5532: Predicted class: 0
# Test example 5533: Predicted class: 7
# Test example 5534: Predicted class: 7
# Test example 5535: Predicted class: 1
# Test example 5536: Predicted class: 1
# Test example 5537: Predicted class: 2
# Test example 5538: Predicted class: 9
# Test example 5539: Predicted class: 3
# Test example 5540: Predicted class: 6
# Test example 5541: Predicted class: 7
# Test example 5542: Predicted class: 2
# Test example 5543: Predicted class: 3
# Test example 5544: Predicted class: 8
# Test example 5545: Predicted class: 1
# Test example 5546: Predicted class: 2
# Test example 5547: Predicted class: 9
# Test example 5548: Predicted class: 8
# Test example 5549: Predicted class: 8
# Test example 5550: Predicted class: 7
# Test example 5551: Predicted class: 1
# Test example 5552: Predicted class: 7
# Test example 5553: Predicted class: 1
# Test example 5554: Predicted class: 1
# Test example 5555: Predicted class: 0
# Test example 5556: Predicted class: 3
# Test example 5557: Predicted class: 4
# Test example 5558: Predicted class: 2
# Test example 5559: Predicted class: 6
# Test example 5560: Predicted class: 4
# Test example 5561: Predicted class: 7
# Test example 5562: Predicted class: 4
# Test example 5563: Predicted class: 2
# Test example 5564: Predicted class: 7
# Test example 5565: Predicted class: 4
# Test example 5566: Predicted class: 9
# Test example 5567: Predicted class: 1
# Test example 5568: Predicted class: 0
# Test example 5569: Predicted class: 6
# Test example 5570: Predicted class: 8
# Test example 5571: Predicted class: 5
# Test example 5572: Predicted class: 5
# Test example 5573: Predicted class: 5
# Test example 5574: Predicted class: 3
# Test example 5575: Predicted class: 5
# Test example 5576: Predicted class: 9
# Test example 5577: Predicted class: 7
# Test example 5578: Predicted class: 4
# Test example 5579: Predicted class: 8
# Test example 5580: Predicted class: 5
# Test example 5581: Predicted class: 9
# Test example 5582: Predicted class: 6
# Test example 5583: Predicted class: 9
# Test example 5584: Predicted class: 3
# Test example 5585: Predicted class: 0
# Test example 5586: Predicted class: 3
# Test example 5587: Predicted class: 8
# Test example 5588: Predicted class: 9
# Test example 5589: Predicted class: 1
# Test example 5590: Predicted class: 8
# Test example 5591: Predicted class: 1
# Test example 5592: Predicted class: 6
# Test example 5593: Predicted class: 0
# Test example 5594: Predicted class: 0
# Test example 5595: Predicted class: 1
# Test example 5596: Predicted class: 2
# Test example 5597: Predicted class: 3
# Test example 5598: Predicted class: 4
# Test example 5599: Predicted class: 5
# Test example 5600: Predicted class: 6
# Test example 5601: Predicted class: 7
# Test example 5602: Predicted class: 8
# Test example 5603: Predicted class: 9
# Test example 5604: Predicted class: 0
# Test example 5605: Predicted class: 1
# Test example 5606: Predicted class: 2
# Test example 5607: Predicted class: 3
# Test example 5608: Predicted class: 4
# Test example 5609: Predicted class: 5
# Test example 5610: Predicted class: 6
# Test example 5611: Predicted class: 7
# Test example 5612: Predicted class: 8
# Test example 5613: Predicted class: 9
# Test example 5614: Predicted class: 0
# Test example 5615: Predicted class: 1
# Test example 5616: Predicted class: 2
# Test example 5617: Predicted class: 3
# Test example 5618: Predicted class: 4
# Test example 5619: Predicted class: 5
# Test example 5620: Predicted class: 6
# Test example 5621: Predicted class: 7
# Test example 5622: Predicted class: 8
# Test example 5623: Predicted class: 9
# Test example 5624: Predicted class: 3
# Test example 5625: Predicted class: 5
# Test example 5626: Predicted class: 3
# Test example 5627: Predicted class: 2
# Test example 5628: Predicted class: 9
# Test example 5629: Predicted class: 3
# Test example 5630: Predicted class: 2
# Test example 5631: Predicted class: 1
# Test example 5632: Predicted class: 4
# Test example 5633: Predicted class: 5
# Test example 5634: Predicted class: 5
# Test example 5635: Predicted class: 2
# Test example 5636: Predicted class: 3
# Test example 5637: Predicted class: 2
# Test example 5638: Predicted class: 1
# Test example 5639: Predicted class: 3
# Test example 5640: Predicted class: 9
# Test example 5641: Predicted class: 7
# Test example 5642: Predicted class: 2
# Test example 5643: Predicted class: 5
# Test example 5644: Predicted class: 2
# Test example 5645: Predicted class: 8
# Test example 5646: Predicted class: 9
# Test example 5647: Predicted class: 1
# Test example 5648: Predicted class: 8
# Test example 5649: Predicted class: 8
# Test example 5650: Predicted class: 7
# Test example 5651: Predicted class: 8
# Test example 5652: Predicted class: 1
# Test example 5653: Predicted class: 0
# Test example 5654: Predicted class: 0
# Test example 5655: Predicted class: 7
# Test example 5656: Predicted class: 7
# Test example 5657: Predicted class: 8
# Test example 5658: Predicted class: 7
# Test example 5659: Predicted class: 5
# Test example 5660: Predicted class: 0
# Test example 5661: Predicted class: 6
# Test example 5662: Predicted class: 1
# Test example 5663: Predicted class: 5
# Test example 5664: Predicted class: 7
# Test example 5665: Predicted class: 4
# Test example 5666: Predicted class: 6
# Test example 5667: Predicted class: 1
# Test example 5668: Predicted class: 2
# Test example 5669: Predicted class: 5
# Test example 5670: Predicted class: 0
# Test example 5671: Predicted class: 7
# Test example 5672: Predicted class: 9
# Test example 5673: Predicted class: 9
# Test example 5674: Predicted class: 0
# Test example 5675: Predicted class: 3
# Test example 5676: Predicted class: 8
# Test example 5677: Predicted class: 2
# Test example 5678: Predicted class: 4
# Test example 5679: Predicted class: 8
# Test example 5680: Predicted class: 1
# Test example 5681: Predicted class: 8
# Test example 5682: Predicted class: 6
# Test example 5683: Predicted class: 5
# Test example 5684: Predicted class: 9
# Test example 5685: Predicted class: 0
# Test example 5686: Predicted class: 0
# Test example 5687: Predicted class: 0
# Test example 5688: Predicted class: 3
# Test example 5689: Predicted class: 7
# Test example 5690: Predicted class: 1
# Test example 5691: Predicted class: 6
# Test example 5692: Predicted class: 4
# Test example 5693: Predicted class: 2
# Test example 5694: Predicted class: 6
# Test example 5695: Predicted class: 6
# Test example 5696: Predicted class: 0
# Test example 5697: Predicted class: 4
# Test example 5698: Predicted class: 5
# Test example 5699: Predicted class: 4
# Test example 5700: Predicted class: 1
# Test example 5701: Predicted class: 3
# Test example 5702: Predicted class: 8
# Test example 5703: Predicted class: 6
# Test example 5704: Predicted class: 3
# Test example 5705: Predicted class: 9
# Test example 5706: Predicted class: 9
# Test example 5707: Predicted class: 5
# Test example 5708: Predicted class: 9
# Test example 5709: Predicted class: 3
# Test example 5710: Predicted class: 7
# Test example 5711: Predicted class: 8
# Test example 5712: Predicted class: 5
# Test example 5713: Predicted class: 6
# Test example 5714: Predicted class: 4
# Test example 5715: Predicted class: 7
# Test example 5716: Predicted class: 6
# Test example 5717: Predicted class: 2
# Test example 5718: Predicted class: 2
# Test example 5719: Predicted class: 0
# Test example 5720: Predicted class: 9
# Test example 5721: Predicted class: 4
# Test example 5722: Predicted class: 0
# Test example 5723: Predicted class: 1
# Test example 5724: Predicted class: 2
# Test example 5725: Predicted class: 3
# Test example 5726: Predicted class: 4
# Test example 5727: Predicted class: 5
# Test example 5728: Predicted class: 6
# Test example 5729: Predicted class: 7
# Test example 5730: Predicted class: 8
# Test example 5731: Predicted class: 9
# Test example 5732: Predicted class: 0
# Test example 5733: Predicted class: 1
# Test example 5734: Predicted class: 2
# Test example 5735: Predicted class: 2
# Test example 5736: Predicted class: 5
# Test example 5737: Predicted class: 6
# Test example 5738: Predicted class: 0
# Test example 5739: Predicted class: 1
# Test example 5740: Predicted class: 2
# Test example 5741: Predicted class: 3
# Test example 5742: Predicted class: 4
# Test example 5743: Predicted class: 5
# Test example 5744: Predicted class: 6
# Test example 5745: Predicted class: 8
# Test example 5746: Predicted class: 7
# Test example 5747: Predicted class: 1
# Test example 5748: Predicted class: 3
# Test example 5749: Predicted class: 2
# Test example 5750: Predicted class: 2
# Test example 5751: Predicted class: 0
# Test example 5752: Predicted class: 7
# Test example 5753: Predicted class: 5
# Test example 5754: Predicted class: 9
# Test example 5755: Predicted class: 9
# Test example 5756: Predicted class: 6
# Test example 5757: Predicted class: 0
# Test example 5758: Predicted class: 9
# Test example 5759: Predicted class: 4
# Test example 5760: Predicted class: 1
# Test example 5761: Predicted class: 3
# Test example 5762: Predicted class: 2
# Test example 5763: Predicted class: 1
# Test example 5764: Predicted class: 2
# Test example 5765: Predicted class: 3
# Test example 5766: Predicted class: 8
# Test example 5767: Predicted class: 3
# Test example 5768: Predicted class: 2
# Test example 5769: Predicted class: 6
# Test example 5770: Predicted class: 5
# Test example 5771: Predicted class: 6
# Test example 5772: Predicted class: 8
# Test example 5773: Predicted class: 2
# Test example 5774: Predicted class: 7
# Test example 5775: Predicted class: 4
# Test example 5776: Predicted class: 8
# Test example 5777: Predicted class: 1
# Test example 5778: Predicted class: 8
# Test example 5779: Predicted class: 0
# Test example 5780: Predicted class: 5
# Test example 5781: Predicted class: 3
# Test example 5782: Predicted class: 9
# Test example 5783: Predicted class: 4
# Test example 5784: Predicted class: 1
# Test example 5785: Predicted class: 9
# Test example 5786: Predicted class: 2
# Test example 5787: Predicted class: 1
# Test example 5788: Predicted class: 9
# Test example 5789: Predicted class: 6
# Test example 5790: Predicted class: 7
# Test example 5791: Predicted class: 9
# Test example 5792: Predicted class: 0
# Test example 5793: Predicted class: 4
# Test example 5794: Predicted class: 6
# Test example 5795: Predicted class: 1
# Test example 5796: Predicted class: 7
# Test example 5797: Predicted class: 3
# Test example 5798: Predicted class: 8
# Test example 5799: Predicted class: 7
# Test example 5800: Predicted class: 2
# Test example 5801: Predicted class: 9
# Test example 5802: Predicted class: 6
# Test example 5803: Predicted class: 5
# Test example 5804: Predicted class: 8
# Test example 5805: Predicted class: 3
# Test example 5806: Predicted class: 9
# Test example 5807: Predicted class: 0
# Test example 5808: Predicted class: 5
# Test example 5809: Predicted class: 7
# Test example 5810: Predicted class: 1
# Test example 5811: Predicted class: 6
# Test example 5812: Predicted class: 1
# Test example 5813: Predicted class: 0
# Test example 5814: Predicted class: 9
# Test example 5815: Predicted class: 3
# Test example 5816: Predicted class: 3
# Test example 5817: Predicted class: 4
# Test example 5818: Predicted class: 4
# Test example 5819: Predicted class: 0
# Test example 5820: Predicted class: 6
# Test example 5821: Predicted class: 2
# Test example 5822: Predicted class: 5
# Test example 5823: Predicted class: 4
# Test example 5824: Predicted class: 2
# Test example 5825: Predicted class: 3
# Test example 5826: Predicted class: 4
# Test example 5827: Predicted class: 6
# Test example 5828: Predicted class: 0
# Test example 5829: Predicted class: 0
# Test example 5830: Predicted class: 2
# Test example 5831: Predicted class: 0
# Test example 5832: Predicted class: 1
# Test example 5833: Predicted class: 4
# Test example 5834: Predicted class: 5
# Test example 5835: Predicted class: 6
# Test example 5836: Predicted class: 9
# Test example 5837: Predicted class: 8
# Test example 5838: Predicted class: 9
# Test example 5839: Predicted class: 0
# Test example 5840: Predicted class: 1
# Test example 5841: Predicted class: 2
# Test example 5842: Predicted class: 3
# Test example 5843: Predicted class: 4
# Test example 5844: Predicted class: 5
# Test example 5845: Predicted class: 6
# Test example 5846: Predicted class: 7
# Test example 5847: Predicted class: 8
# Test example 5848: Predicted class: 0
# Test example 5849: Predicted class: 1
# Test example 5850: Predicted class: 2
# Test example 5851: Predicted class: 3
# Test example 5852: Predicted class: 4
# Test example 5853: Predicted class: 5
# Test example 5854: Predicted class: 6
# Test example 5855: Predicted class: 7
# Test example 5856: Predicted class: 8
# Test example 5857: Predicted class: 9
# Test example 5858: Predicted class: 8
# Test example 5859: Predicted class: 7
# Test example 5860: Predicted class: 1
# Test example 5861: Predicted class: 3
# Test example 5862: Predicted class: 7
# Test example 5863: Predicted class: 5
# Test example 5864: Predicted class: 2
# Test example 5865: Predicted class: 8
# Test example 5866: Predicted class: 0
# Test example 5867: Predicted class: 7
# Test example 5868: Predicted class: 5
# Test example 5869: Predicted class: 9
# Test example 5870: Predicted class: 9
# Test example 5871: Predicted class: 0
# Test example 5872: Predicted class: 9
# Test example 5873: Predicted class: 1
# Test example 5874: Predicted class: 1
# Test example 5875: Predicted class: 5
# Test example 5876: Predicted class: 8
# Test example 5877: Predicted class: 8
# Test example 5878: Predicted class: 6
# Test example 5879: Predicted class: 3
# Test example 5880: Predicted class: 2
# Test example 5881: Predicted class: 1
# Test example 5882: Predicted class: 8
# Test example 5883: Predicted class: 3
# Test example 5884: Predicted class: 2
# Test example 5885: Predicted class: 6
# Test example 5886: Predicted class: 5
# Test example 5887: Predicted class: 6
# Test example 5888: Predicted class: 5
# Test example 5889: Predicted class: 4
# Test example 5890: Predicted class: 1
# Test example 5891: Predicted class: 0
# Test example 5892: Predicted class: 5
# Test example 5893: Predicted class: 3
# Test example 5894: Predicted class: 1
# Test example 5895: Predicted class: 9
# Test example 5896: Predicted class: 2
# Test example 5897: Predicted class: 1
# Test example 5898: Predicted class: 9
# Test example 5899: Predicted class: 6
# Test example 5900: Predicted class: 0
# Test example 5901: Predicted class: 4
# Test example 5902: Predicted class: 6
# Test example 5903: Predicted class: 1
# Test example 5904: Predicted class: 7
# Test example 5905: Predicted class: 3
# Test example 5906: Predicted class: 8
# Test example 5907: Predicted class: 7
# Test example 5908: Predicted class: 2
# Test example 5909: Predicted class: 9
# Test example 5910: Predicted class: 6
# Test example 5911: Predicted class: 5
# Test example 5912: Predicted class: 8
# Test example 5913: Predicted class: 3
# Test example 5914: Predicted class: 5
# Test example 5915: Predicted class: 7
# Test example 5916: Predicted class: 1
# Test example 5917: Predicted class: 6
# Test example 5918: Predicted class: 1
# Test example 5919: Predicted class: 0
# Test example 5920: Predicted class: 9
# Test example 5921: Predicted class: 6
# Test example 5922: Predicted class: 2
# Test example 5923: Predicted class: 5
# Test example 5924: Predicted class: 4
# Test example 5925: Predicted class: 2
# Test example 5926: Predicted class: 3
# Test example 5927: Predicted class: 4
# Test example 5928: Predicted class: 4
# Test example 5929: Predicted class: 6
# Test example 5930: Predicted class: 0
# Test example 5931: Predicted class: 0
# Test example 5932: Predicted class: 2
# Test example 5933: Predicted class: 0
# Test example 5934: Predicted class: 1
# Test example 5935: Predicted class: 2
# Test example 5936: Predicted class: 3
# Test example 5937: Predicted class: 9
# Test example 5938: Predicted class: 3
# Test example 5939: Predicted class: 6
# Test example 5940: Predicted class: 7
# Test example 5941: Predicted class: 8
# Test example 5942: Predicted class: 9
# Test example 5943: Predicted class: 0
# Test example 5944: Predicted class: 1
# Test example 5945: Predicted class: 2
# Test example 5946: Predicted class: 3
# Test example 5947: Predicted class: 4
# Test example 5948: Predicted class: 5
# Test example 5949: Predicted class: 6
# Test example 5950: Predicted class: 7
# Test example 5951: Predicted class: 8
# Test example 5952: Predicted class: 9
# Test example 5953: Predicted class: 0
# Test example 5954: Predicted class: 1
# Test example 5955: Predicted class: 2
# Test example 5956: Predicted class: 8
# Test example 5957: Predicted class: 4
# Test example 5958: Predicted class: 5
# Test example 5959: Predicted class: 6
# Test example 5960: Predicted class: 7
# Test example 5961: Predicted class: 8
# Test example 5962: Predicted class: 9
# Test example 5963: Predicted class: 8
# Test example 5964: Predicted class: 6
# Test example 5965: Predicted class: 5
# Test example 5966: Predicted class: 0
# Test example 5967: Predicted class: 6
# Test example 5968: Predicted class: 8
# Test example 5969: Predicted class: 9
# Test example 5970: Predicted class: 4
# Test example 5971: Predicted class: 1
# Test example 5972: Predicted class: 9
# Test example 5973: Predicted class: 3
# Test example 5974: Predicted class: 9
# Test example 5975: Predicted class: 0
# Test example 5976: Predicted class: 4
# Test example 5977: Predicted class: 8
# Test example 5978: Predicted class: 9
# Test example 5979: Predicted class: 1
# Test example 5980: Predicted class: 4
# Test example 5981: Predicted class: 0
# Test example 5982: Predicted class: 5
# Test example 5983: Predicted class: 5
# Test example 5984: Predicted class: 2
# Test example 5985: Predicted class: 1
# Test example 5986: Predicted class: 5
# Test example 5987: Predicted class: 4
# Test example 5988: Predicted class: 0
# Test example 5989: Predicted class: 7
# Test example 5990: Predicted class: 6
# Test example 5991: Predicted class: 0
# Test example 5992: Predicted class: 1
# Test example 5993: Predicted class: 7
# Test example 5994: Predicted class: 0
# Test example 5995: Predicted class: 6
# Test example 5996: Predicted class: 8
# Test example 5997: Predicted class: 9
# Test example 5998: Predicted class: 9
# Test example 5999: Predicted class: 1
# Test example 6000: Predicted class: 7
# Test example 6001: Predicted class: 9
# Test example 6002: Predicted class: 8
# Test example 6003: Predicted class: 6
# Test example 6004: Predicted class: 0
# Test example 6005: Predicted class: 8
# Test example 6006: Predicted class: 1
# Test example 6007: Predicted class: 7
# Test example 6008: Predicted class: 7
# Test example 6009: Predicted class: 1
# Test example 6010: Predicted class: 3
# Test example 6011: Predicted class: 2
# Test example 6012: Predicted class: 3
# Test example 6013: Predicted class: 1
# Test example 6014: Predicted class: 4
# Test example 6015: Predicted class: 2
# Test example 6016: Predicted class: 0
# Test example 6017: Predicted class: 0
# Test example 6018: Predicted class: 7
# Test example 6019: Predicted class: 8
# Test example 6020: Predicted class: 4
# Test example 6021: Predicted class: 6
# Test example 6022: Predicted class: 4
# Test example 6023: Predicted class: 9
# Test example 6024: Predicted class: 9
# Test example 6025: Predicted class: 8
# Test example 6026: Predicted class: 4
# Test example 6027: Predicted class: 7
# Test example 6028: Predicted class: 2
# Test example 6029: Predicted class: 5
# Test example 6030: Predicted class: 6
# Test example 6031: Predicted class: 3
# Test example 6032: Predicted class: 6
# Test example 6033: Predicted class: 9
# Test example 6034: Predicted class: 6
# Test example 6035: Predicted class: 3
# Test example 6036: Predicted class: 2
# Test example 6037: Predicted class: 2
# Test example 6038: Predicted class: 4
# Test example 6039: Predicted class: 6
# Test example 6040: Predicted class: 9
# Test example 6041: Predicted class: 0
# Test example 6042: Predicted class: 2
# Test example 6043: Predicted class: 5
# Test example 6044: Predicted class: 5
# Test example 6045: Predicted class: 1
# Test example 6046: Predicted class: 9
# Test example 6047: Predicted class: 3
# Test example 6048: Predicted class: 9
# Test example 6049: Predicted class: 7
# Test example 6050: Predicted class: 8
# Test example 6051: Predicted class: 7
# Test example 6052: Predicted class: 2
# Test example 6053: Predicted class: 2
# Test example 6054: Predicted class: 5
# Test example 6055: Predicted class: 7
# Test example 6056: Predicted class: 9
# Test example 6057: Predicted class: 8
# Test example 6058: Predicted class: 2
# Test example 6059: Predicted class: 1
# Test example 6060: Predicted class: 9
# Test example 6061: Predicted class: 1
# Test example 6062: Predicted class: 3
# Test example 6063: Predicted class: 0
# Test example 6064: Predicted class: 1
# Test example 6065: Predicted class: 2
# Test example 6066: Predicted class: 8
# Test example 6067: Predicted class: 4
# Test example 6068: Predicted class: 5
# Test example 6069: Predicted class: 6
# Test example 6070: Predicted class: 7
# Test example 6071: Predicted class: 8
# Test example 6072: Predicted class: 9
# Test example 6073: Predicted class: 0
# Test example 6074: Predicted class: 1
# Test example 6075: Predicted class: 2
# Test example 6076: Predicted class: 3
# Test example 6077: Predicted class: 4
# Test example 6078: Predicted class: 5
# Test example 6079: Predicted class: 6
# Test example 6080: Predicted class: 7
# Test example 6081: Predicted class: 8
# Test example 6082: Predicted class: 9
# Test example 6083: Predicted class: 0
# Test example 6084: Predicted class: 1
# Test example 6085: Predicted class: 2
# Test example 6086: Predicted class: 3
# Test example 6087: Predicted class: 4
# Test example 6088: Predicted class: 5
# Test example 6089: Predicted class: 6
# Test example 6090: Predicted class: 7
# Test example 6091: Predicted class: 8
# Test example 6092: Predicted class: 9
# Test example 6093: Predicted class: 1
# Test example 6094: Predicted class: 2
# Test example 6095: Predicted class: 6
# Test example 6096: Predicted class: 5
# Test example 6097: Predicted class: 3
# Test example 6098: Predicted class: 0
# Test example 6099: Predicted class: 7
# Test example 6100: Predicted class: 0
# Test example 6101: Predicted class: 4
# Test example 6102: Predicted class: 1
# Test example 6103: Predicted class: 4
# Test example 6104: Predicted class: 3
# Test example 6105: Predicted class: 6
# Test example 6106: Predicted class: 7
# Test example 6107: Predicted class: 2
# Test example 6108: Predicted class: 3
# Test example 6109: Predicted class: 1
# Test example 6110: Predicted class: 2
# Test example 6111: Predicted class: 1
# Test example 6112: Predicted class: 2
# Test example 6113: Predicted class: 9
# Test example 6114: Predicted class: 6
# Test example 6115: Predicted class: 0
# Test example 6116: Predicted class: 1
# Test example 6117: Predicted class: 3
# Test example 6118: Predicted class: 0
# Test example 6119: Predicted class: 2
# Test example 6120: Predicted class: 7
# Test example 6121: Predicted class: 5
# Test example 6122: Predicted class: 7
# Test example 6123: Predicted class: 6
# Test example 6124: Predicted class: 2
# Test example 6125: Predicted class: 9
# Test example 6126: Predicted class: 1
# Test example 6127: Predicted class: 9
# Test example 6128: Predicted class: 0
# Test example 6129: Predicted class: 6
# Test example 6130: Predicted class: 0
# Test example 6131: Predicted class: 6
# Test example 6132: Predicted class: 0
# Test example 6133: Predicted class: 2
# Test example 6134: Predicted class: 0
# Test example 6135: Predicted class: 6
# Test example 6136: Predicted class: 1
# Test example 6137: Predicted class: 5
# Test example 6138: Predicted class: 8
# Test example 6139: Predicted class: 4
# Test example 6140: Predicted class: 3
# Test example 6141: Predicted class: 0
# Test example 6142: Predicted class: 1
# Test example 6143: Predicted class: 5
# Test example 6144: Predicted class: 4
# Test example 6145: Predicted class: 4
# Test example 6146: Predicted class: 8
# Test example 6147: Predicted class: 5
# Test example 6148: Predicted class: 7
# Test example 6149: Predicted class: 5
# Test example 6150: Predicted class: 7
# Test example 6151: Predicted class: 8
# Test example 6152: Predicted class: 3
# Test example 6153: Predicted class: 4
# Test example 6154: Predicted class: 8
# Test example 6155: Predicted class: 8
# Test example 6156: Predicted class: 5
# Test example 6157: Predicted class: 2
# Test example 6158: Predicted class: 9
# Test example 6159: Predicted class: 7
# Test example 6160: Predicted class: 1
# Test example 6161: Predicted class: 3
# Test example 6162: Predicted class: 8
# Test example 6163: Predicted class: 1
# Test example 6164: Predicted class: 0
# Test example 6165: Predicted class: 7
# Test example 6166: Predicted class: 5
# Test example 6167: Predicted class: 3
# Test example 6168: Predicted class: 6
# Test example 6169: Predicted class: 9
# Test example 6170: Predicted class: 4
# Test example 6171: Predicted class: 7
# Test example 6172: Predicted class: 7
# Test example 6173: Predicted class: 9
# Test example 6174: Predicted class: 8
# Test example 6175: Predicted class: 3
# Test example 6176: Predicted class: 4
# Test example 6177: Predicted class: 4
# Test example 6178: Predicted class: 3
# Test example 6179: Predicted class: 8
# Test example 6180: Predicted class: 6
# Test example 6181: Predicted class: 2
# Test example 6182: Predicted class: 0
# Test example 6183: Predicted class: 1
# Test example 6184: Predicted class: 2
# Test example 6185: Predicted class: 3
# Test example 6186: Predicted class: 4
# Test example 6187: Predicted class: 5
# Test example 6188: Predicted class: 6
# Test example 6189: Predicted class: 7
# Test example 6190: Predicted class: 8
# Test example 6191: Predicted class: 9
# Test example 6192: Predicted class: 0
# Test example 6193: Predicted class: 1
# Test example 6194: Predicted class: 2
# Test example 6195: Predicted class: 3
# Test example 6196: Predicted class: 4
# Test example 6197: Predicted class: 5
# Test example 6198: Predicted class: 6
# Test example 6199: Predicted class: 7
# Test example 6200: Predicted class: 8
# Test example 6201: Predicted class: 9
# Test example 6202: Predicted class: 0
# Test example 6203: Predicted class: 1
# Test example 6204: Predicted class: 2
# Test example 6205: Predicted class: 3
# Test example 6206: Predicted class: 4
# Test example 6207: Predicted class: 5
# Test example 6208: Predicted class: 6
# Test example 6209: Predicted class: 7
# Test example 6210: Predicted class: 8
# Test example 6211: Predicted class: 9
# Test example 6212: Predicted class: 0
# Test example 6213: Predicted class: 8
# Test example 6214: Predicted class: 3
# Test example 6215: Predicted class: 9
# Test example 6216: Predicted class: 5
# Test example 6217: Predicted class: 5
# Test example 6218: Predicted class: 2
# Test example 6219: Predicted class: 6
# Test example 6220: Predicted class: 8
# Test example 6221: Predicted class: 4
# Test example 6222: Predicted class: 9
# Test example 6223: Predicted class: 1
# Test example 6224: Predicted class: 7
# Test example 6225: Predicted class: 1
# Test example 6226: Predicted class: 2
# Test example 6227: Predicted class: 3
# Test example 6228: Predicted class: 5
# Test example 6229: Predicted class: 9
# Test example 6230: Predicted class: 6
# Test example 6231: Predicted class: 9
# Test example 6232: Predicted class: 1
# Test example 6233: Predicted class: 1
# Test example 6234: Predicted class: 1
# Test example 6235: Predicted class: 2
# Test example 6236: Predicted class: 9
# Test example 6237: Predicted class: 5
# Test example 6238: Predicted class: 6
# Test example 6239: Predicted class: 8
# Test example 6240: Predicted class: 1
# Test example 6241: Predicted class: 2
# Test example 6242: Predicted class: 0
# Test example 6243: Predicted class: 7
# Test example 6244: Predicted class: 7
# Test example 6245: Predicted class: 5
# Test example 6246: Predicted class: 8
# Test example 6247: Predicted class: 2
# Test example 6248: Predicted class: 9
# Test example 6249: Predicted class: 8
# Test example 6250: Predicted class: 9
# Test example 6251: Predicted class: 0
# Test example 6252: Predicted class: 4
# Test example 6253: Predicted class: 6
# Test example 6254: Predicted class: 7
# Test example 6255: Predicted class: 1
# Test example 6256: Predicted class: 3
# Test example 6257: Predicted class: 4
# Test example 6258: Predicted class: 5
# Test example 6259: Predicted class: 6
# Test example 6260: Predicted class: 0
# Test example 6261: Predicted class: 3
# Test example 6262: Predicted class: 6
# ...
# Test example 9581: Predicted class: 9
# Test example 9582: Predicted class: 3
# Test example 9583: Predicted class: 3
# Test example 9584: Predicted class: 5
# Test example 9585: Predicted class: 5
# Test example 9586: Predicted class: 0
# Test example 9587: Predicted class: 7
# Test example 9588: Predicted class: 4
# Test example 9589: Predicted class: 5
# Test example 9590: Predicted class: 6
# Test example 9591: Predicted class: 5
# Test example 9592: Predicted class: 1
# Test example 9593: Predicted class: 4
# Test example 9594: Predicted class: 1
# Test example 9595: Predicted class: 1
# Test example 9596: Predicted class: 2
# Test example 9597: Predicted class: 8
# Test example 9598: Predicted class: 2
# Test example 9599: Predicted class: 6
# Test example 9600: Predicted class: 1
# Test example 9601: Predicted class: 5
# Test example 9602: Predicted class: 0
# Test example 9603: Predicted class: 1
# Test example 9604: Predicted class: 2
# Test example 9605: Predicted class: 3
# Test example 9606: Predicted class: 4
# Test example 9607: Predicted class: 5
# Test example 9608: Predicted class: 6
# Test example 9609: Predicted class: 7
# Test example 9610: Predicted class: 8
# Test example 9611: Predicted class: 9
# Test example 9612: Predicted class: 0
# Test example 9613: Predicted class: 1
# Test example 9614: Predicted class: 2
# Test example 9615: Predicted class: 3
# Test example 9616: Predicted class: 4
# Test example 9617: Predicted class: 5
# Test example 9618: Predicted class: 6
# Test example 9619: Predicted class: 7
# Test example 9620: Predicted class: 8
# Test example 9621: Predicted class: 9
# Test example 9622: Predicted class: 0
# Test example 9623: Predicted class: 1
# Test example 9624: Predicted class: 2
# Test example 9625: Predicted class: 3
# Test example 9626: Predicted class: 4
# Test example 9627: Predicted class: 5
# Test example 9628: Predicted class: 6
# Test example 9629: Predicted class: 7
# Test example 9630: Predicted class: 8
# Test example 9631: Predicted class: 8
# Test example 9632: Predicted class: 0
# Test example 9633: Predicted class: 6
# Test example 9634: Predicted class: 0
# Test example 9635: Predicted class: 1
# Test example 9636: Predicted class: 2
# Test example 9637: Predicted class: 3
# Test example 9638: Predicted class: 7
# Test example 9639: Predicted class: 9
# Test example 9640: Predicted class: 4
# Test example 9641: Predicted class: 7
# Test example 9642: Predicted class: 1
# Test example 9643: Predicted class: 9
# Test example 9644: Predicted class: 1
# Test example 9645: Predicted class: 7
# Test example 9646: Predicted class: 1
# Test example 9647: Predicted class: 4
# Test example 9648: Predicted class: 0
# Test example 9649: Predicted class: 0
# Test example 9650: Predicted class: 1
# Test example 9651: Predicted class: 7
# Test example 9652: Predicted class: 5
# Test example 9653: Predicted class: 7
# Test example 9654: Predicted class: 1
# Test example 9655: Predicted class: 3
# Test example 9656: Predicted class: 3
# Test example 9657: Predicted class: 3
# Test example 9658: Predicted class: 1
# Test example 9659: Predicted class: 6
# Test example 9660: Predicted class: 9
# Test example 9661: Predicted class: 7
# Test example 9662: Predicted class: 1
# Test example 9663: Predicted class: 3
# Test example 9664: Predicted class: 0
# Test example 9665: Predicted class: 7
# Test example 9666: Predicted class: 6
# Test example 9667: Predicted class: 0
# Test example 9668: Predicted class: 8
# Test example 9669: Predicted class: 9
# Test example 9670: Predicted class: 4
# Test example 9671: Predicted class: 3
# Test example 9672: Predicted class: 5
# Test example 9673: Predicted class: 4
# Test example 9674: Predicted class: 8
# Test example 9675: Predicted class: 1
# Test example 9676: Predicted class: 5
# Test example 9677: Predicted class: 9
# Test example 9678: Predicted class: 0
# Test example 9679: Predicted class: 6
# Test example 9680: Predicted class: 3
# Test example 9681: Predicted class: 3
# Test example 9682: Predicted class: 8
# Test example 9683: Predicted class: 1
# Test example 9684: Predicted class: 4
# Test example 9685: Predicted class: 7
# Test example 9686: Predicted class: 5
# Test example 9687: Predicted class: 2
# Test example 9688: Predicted class: 0
# Test example 9689: Predicted class: 0
# Test example 9690: Predicted class: 1
# Test example 9691: Predicted class: 7
# Test example 9692: Predicted class: 8
# Test example 9693: Predicted class: 7
# Test example 9694: Predicted class: 6
# Test example 9695: Predicted class: 8
# Test example 9696: Predicted class: 8
# Test example 9697: Predicted class: 2
# Test example 9698: Predicted class: 3
# Test example 9699: Predicted class: 5
# Test example 9700: Predicted class: 1
# Test example 9701: Predicted class: 2
# Test example 9702: Predicted class: 9
# Test example 9703: Predicted class: 5
# Test example 9704: Predicted class: 2
# Test example 9705: Predicted class: 0
# Test example 9706: Predicted class: 1
# Test example 9707: Predicted class: 2
# Test example 9708: Predicted class: 3
# Test example 9709: Predicted class: 4
# Test example 9710: Predicted class: 5
# Test example 9711: Predicted class: 6
# Test example 9712: Predicted class: 7
# Test example 9713: Predicted class: 8
# Test example 9714: Predicted class: 9
# Test example 9715: Predicted class: 0
# Test example 9716: Predicted class: 1
# Test example 9717: Predicted class: 2
# Test example 9718: Predicted class: 3
# Test example 9719: Predicted class: 4
# Test example 9720: Predicted class: 5
# Test example 9721: Predicted class: 6
# Test example 9722: Predicted class: 7
# Test example 9723: Predicted class: 8
# Test example 9724: Predicted class: 9
# Test example 9725: Predicted class: 0
# Test example 9726: Predicted class: 1
# Test example 9727: Predicted class: 2
# Test example 9728: Predicted class: 3
# Test example 9729: Predicted class: 4
# Test example 9730: Predicted class: 6
# Test example 9731: Predicted class: 6
# Test example 9732: Predicted class: 7
# Test example 9733: Predicted class: 8
# Test example 9734: Predicted class: 9
# Test example 9735: Predicted class: 7
# Test example 9736: Predicted class: 4
# Test example 9737: Predicted class: 6
# Test example 9738: Predicted class: 1
# Test example 9739: Predicted class: 4
# Test example 9740: Predicted class: 0
# Test example 9741: Predicted class: 9
# Test example 9742: Predicted class: 9
# Test example 9743: Predicted class: 3
# Test example 9744: Predicted class: 7
# Test example 9745: Predicted class: 8
# Test example 9746: Predicted class: 0
# Test example 9747: Predicted class: 7
# Test example 9748: Predicted class: 5
# Test example 9749: Predicted class: 8
# Test example 9750: Predicted class: 6
# Test example 9751: Predicted class: 3
# Test example 9752: Predicted class: 2
# Test example 9753: Predicted class: 2
# Test example 9754: Predicted class: 0
# Test example 9755: Predicted class: 5
# Test example 9756: Predicted class: 8
# Test example 9757: Predicted class: 6
# Test example 9758: Predicted class: 0
# Test example 9759: Predicted class: 3
# Test example 9760: Predicted class: 8
# Test example 9761: Predicted class: 1
# Test example 9762: Predicted class: 0
# Test example 9763: Predicted class: 3
# Test example 9764: Predicted class: 0
# Test example 9765: Predicted class: 4
# Test example 9766: Predicted class: 7
# Test example 9767: Predicted class: 4
# Test example 9768: Predicted class: 9
# Test example 9769: Predicted class: 0
# Test example 9770: Predicted class: 9
# Test example 9771: Predicted class: 0
# Test example 9772: Predicted class: 7
# Test example 9773: Predicted class: 1
# Test example 9774: Predicted class: 7
# Test example 9775: Predicted class: 1
# Test example 9776: Predicted class: 6
# Test example 9777: Predicted class: 6
# Test example 9778: Predicted class: 0
# Test example 9779: Predicted class: 6
# Test example 9780: Predicted class: 2
# Test example 9781: Predicted class: 8
# Test example 9782: Predicted class: 7
# Test example 9783: Predicted class: 6
# Test example 9784: Predicted class: 4
# Test example 9785: Predicted class: 9
# Test example 9786: Predicted class: 9
# Test example 9787: Predicted class: 5
# Test example 9788: Predicted class: 3
# Test example 9789: Predicted class: 7
# Test example 9790: Predicted class: 4
# Test example 9791: Predicted class: 3
# Test example 9792: Predicted class: 0
# Test example 9793: Predicted class: 4
# Test example 9794: Predicted class: 6
# Test example 9795: Predicted class: 6
# Test example 9796: Predicted class: 1
# Test example 9797: Predicted class: 1
# Test example 9798: Predicted class: 3
# Test example 9799: Predicted class: 2
# Test example 9800: Predicted class: 1
# Test example 9801: Predicted class: 0
# Test example 9802: Predicted class: 0
# Test example 9803: Predicted class: 1
# Test example 9804: Predicted class: 2
# Test example 9805: Predicted class: 3
# Test example 9806: Predicted class: 4
# Test example 9807: Predicted class: 7
# Test example 9808: Predicted class: 8
# Test example 9809: Predicted class: 9
# Test example 9810: Predicted class: 0
# Test example 9811: Predicted class: 1
# Test example 9812: Predicted class: 2
# Test example 9813: Predicted class: 3
# Test example 9814: Predicted class: 4
# Test example 9815: Predicted class: 5
# Test example 9816: Predicted class: 6
# Test example 9817: Predicted class: 7
# Test example 9818: Predicted class: 8
# Test example 9819: Predicted class: 0
# Test example 9820: Predicted class: 1
# Test example 9821: Predicted class: 2
# Test example 9822: Predicted class: 3
# Test example 9823: Predicted class: 4
# Test example 9824: Predicted class: 7
# Test example 9825: Predicted class: 8
# Test example 9826: Predicted class: 9
# Test example 9827: Predicted class: 0
# Test example 9828: Predicted class: 8
# Test example 9829: Predicted class: 3
# Test example 9830: Predicted class: 9
# Test example 9831: Predicted class: 5
# Test example 9832: Predicted class: 5
# Test example 9833: Predicted class: 2
# Test example 9834: Predicted class: 6
# Test example 9835: Predicted class: 8
# Test example 9836: Predicted class: 4
# Test example 9837: Predicted class: 1
# Test example 9838: Predicted class: 7
# Test example 9839: Predicted class: 1
# Test example 9840: Predicted class: 7
# Test example 9841: Predicted class: 3
# Test example 9842: Predicted class: 5
# Test example 9843: Predicted class: 6
# Test example 9844: Predicted class: 9
# Test example 9845: Predicted class: 1
# Test example 9846: Predicted class: 1
# Test example 9847: Predicted class: 1
# Test example 9848: Predicted class: 2
# Test example 9849: Predicted class: 1
# Test example 9850: Predicted class: 2
# Test example 9851: Predicted class: 0
# Test example 9852: Predicted class: 7
# Test example 9853: Predicted class: 7
# Test example 9854: Predicted class: 5
# Test example 9855: Predicted class: 8
# Test example 9856: Predicted class: 2
# Test example 9857: Predicted class: 9
# Test example 9858: Predicted class: 8
# Test example 9859: Predicted class: 6
# Test example 9860: Predicted class: 7
# Test example 9861: Predicted class: 3
# Test example 9862: Predicted class: 4
# Test example 9863: Predicted class: 6
# Test example 9864: Predicted class: 8
# Test example 9865: Predicted class: 7
# Test example 9866: Predicted class: 0
# Test example 9867: Predicted class: 4
# Test example 9868: Predicted class: 2
# Test example 9869: Predicted class: 7
# Test example 9870: Predicted class: 7
# Test example 9871: Predicted class: 5
# Test example 9872: Predicted class: 4
# Test example 9873: Predicted class: 3
# Test example 9874: Predicted class: 4
# Test example 9875: Predicted class: 2
# Test example 9876: Predicted class: 8
# Test example 9877: Predicted class: 1
# Test example 9878: Predicted class: 5
# Test example 9879: Predicted class: 1
# Test example 9880: Predicted class: 0
# Test example 9881: Predicted class: 2
# Test example 9882: Predicted class: 3
# Test example 9883: Predicted class: 3
# Test example 9884: Predicted class: 5
# Test example 9885: Predicted class: 7
# Test example 9886: Predicted class: 0
# Test example 9887: Predicted class: 6
# Test example 9888: Predicted class: 8
# Test example 9889: Predicted class: 6
# Test example 9890: Predicted class: 3
# Test example 9891: Predicted class: 9
# Test example 9892: Predicted class: 9
# Test example 9893: Predicted class: 8
# Test example 9894: Predicted class: 2
# Test example 9895: Predicted class: 7
# Test example 9896: Predicted class: 7
# Test example 9897: Predicted class: 1
# Test example 9898: Predicted class: 0
# Test example 9899: Predicted class: 1
# Test example 9900: Predicted class: 7
# Test example 9901: Predicted class: 8
# Test example 9902: Predicted class: 9
# Test example 9903: Predicted class: 0
# Test example 9904: Predicted class: 1
# Test example 9905: Predicted class: 2
# Test example 9906: Predicted class: 3
# Test example 9907: Predicted class: 4
# Test example 9908: Predicted class: 5
# Test example 9909: Predicted class: 6
# Test example 9910: Predicted class: 7
# Test example 9911: Predicted class: 8
# Test example 9912: Predicted class: 0
# Test example 9913: Predicted class: 1
# Test example 9914: Predicted class: 2
# Test example 9915: Predicted class: 3
# Test example 9916: Predicted class: 4
# Test example 9917: Predicted class: 7
# Test example 9918: Predicted class: 8
# Test example 9919: Predicted class: 9
# Test example 9920: Predicted class: 7
# Test example 9921: Predicted class: 8
# Test example 9922: Predicted class: 6
# Test example 9923: Predicted class: 4
# Test example 9924: Predicted class: 1
# Test example 9925: Predicted class: 9
# Test example 9926: Predicted class: 3
# Test example 9927: Predicted class: 8
# Test example 9928: Predicted class: 4
# Test example 9929: Predicted class: 4
# Test example 9930: Predicted class: 7
# Test example 9931: Predicted class: 0
# Test example 9932: Predicted class: 1
# Test example 9933: Predicted class: 9
# Test example 9934: Predicted class: 2
# Test example 9935: Predicted class: 8
# Test example 9936: Predicted class: 7
# Test example 9937: Predicted class: 8
# Test example 9938: Predicted class: 2
# Test example 9939: Predicted class: 6
# Test example 9940: Predicted class: 0
# Test example 9941: Predicted class: 6
# Test example 9942: Predicted class: 5
# Test example 9943: Predicted class: 3
# Test example 9944: Predicted class: 3
# Test example 9945: Predicted class: 3
# Test example 9946: Predicted class: 9
# Test example 9947: Predicted class: 1
# Test example 9948: Predicted class: 4
# Test example 9949: Predicted class: 0
# Test example 9950: Predicted class: 6
# Test example 9951: Predicted class: 1
# Test example 9952: Predicted class: 0
# Test example 9953: Predicted class: 0
# Test example 9954: Predicted class: 6
# Test example 9955: Predicted class: 2
# Test example 9956: Predicted class: 1
# Test example 9957: Predicted class: 1
# Test example 9958: Predicted class: 7
# Test example 9959: Predicted class: 7
# Test example 9960: Predicted class: 8
# Test example 9961: Predicted class: 4
# Test example 9962: Predicted class: 6
# Test example 9963: Predicted class: 0
# Test example 9964: Predicted class: 7
# Test example 9965: Predicted class: 0
# Test example 9966: Predicted class: 3
# Test example 9967: Predicted class: 6
# Test example 9968: Predicted class: 8
# Test example 9969: Predicted class: 7
# Test example 9970: Predicted class: 1
# Test example 9971: Predicted class: 5
# Test example 9972: Predicted class: 2
# Test example 9973: Predicted class: 4
# Test example 9974: Predicted class: 9
# Test example 9975: Predicted class: 4
# Test example 9976: Predicted class: 2
# Test example 9977: Predicted class: 6
# Test example 9978: Predicted class: 4
# Test example 9979: Predicted class: 1
# Test example 9980: Predicted class: 7
# Test example 9981: Predicted class: 2
# Test example 9982: Predicted class: 6
# Test example 9983: Predicted class: 6
# Test example 9984: Predicted class: 0
# Test example 9985: Predicted class: 1
# Test example 9986: Predicted class: 2
# Test example 9987: Predicted class: 3
# Test example 9988: Predicted class: 4
# Test example 9989: Predicted class: 5
# Test example 9990: Predicted class: 6
# Test example 9991: Predicted class: 7
# Test example 9992: Predicted class: 8
# Test example 9993: Predicted class: 9
# Test example 9994: Predicted class: 0
# Test example 9995: Predicted class: 1
# Test example 9996: Predicted class: 2
# Test example 9997: Predicted class: 3
# Test example 9998: Predicted class: 4
# Test example 9999: Predicted class: 5
# Test example 10000: Predicted class: 6
# Test Accuracy: 97.93%

# %%
from sklearn.metrics import confusion_matrix

# Convert one-hot encoded test predictions to class labels
test_pred_labels = np.argmax(test_predictions, axis=0)

# Convert one-hot encoded true labels to class labels
test_true_labels = np.argmax(test_y_one_hot, axis=1)

# Calculate the confusion matrix
conf_matrix = confusion_matrix(test_true_labels, test_pred_labels)

print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[ 969    1    1    2    1    1    3    1    1    0]
#  [   0 1126    2    0    0    1    2    1    2    1]
#  [   3    0 1012    2    2    0    3    5    5    0]
#  [   0    1    4  991    0    2    0    5    3    4]
#  [   1    0    1    0  959    0    5    1    1   14]
#  [   4    0    0   11    1  861    5    1    5    4]
#  [   7    3    0    1    3    5  936    0    3    0]
#  [   0    3    6    2    0    1    0 1007    3    6]
#  [   3    0    5    5    3    2    1    3  950    2]
#  [   2    2    0    5    8    3    0    5    2  982]]

# %%
def calculate_confusion_matrix(true_labels, predicted_labels, num_classes=10):

    conf_matrix = np.zeros((num_classes, num_classes), dtype=int)

    # Fill the confusion matrix
    for true_label, predicted_label in zip(true_labels, predicted_labels):
        conf_matrix[true_label, predicted_label] += 1

    return conf_matrix

conf_matrix = calculate_confusion_matrix(test_true_labels, test_pred_labels)
print(conf_matrix)
# Out:
# [[ 969    1    1    2    1    1    3    1    1    0]
#  [   0 1126    2    0    0    1    2    1    2    1]
#  [   3    0 1012    2    2    0    3    5    5    0]
#  [   0    1    4  991    0    2    0    5    3    4]
#  [   1    0    1    0  959    0    5    1    1   14]
#  [   4    0    0   11    1  861    5    1    5    4]
#  [   7    3    0    1    3    5  936    0    3    0]
#  [   0    3    6    2    0    1    0 1007    3    6]
#  [   3    0    5    5    3    2    1    3  950    2]
#  [   2    2    0    5    8    3    0    5    2  982]]
